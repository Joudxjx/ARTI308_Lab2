# %%
import pandas as pd

df = pd.read_csv('movies.csv')

print(f"Dataset Shape: {df.shape}")

print("\n--- Dataset Preview ---")
display(df.head())

print("\n--- Column Information ---")
print(df.info())

print("\n--- Missing Values ---")
print(df.isnull().sum())
# Out:
# Dataset Shape: (8560, 8)
#
# --- Dataset Preview ---
#    Unnamed: 0   id                     title  \
# 0           0  278  The Shawshank Redemption
# 1           1  238             The Godfather
# 2           2  240     The Godfather Part II
# 3           3  424          Schindler's List
# 4           4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     37.2512
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     30.7590
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     14.5889
# 3  The true story of how businessman Oskar Schind...   1993-12-15     14.1156
# 4  The defense and the prosecution have rested an...   1957-04-10     11.8666
#
#    vote_average  vote_count
# 0         8.713       29484
# 1         8.685       22254
# 2         8.571       13460
# 3         8.565       16977
# ...
